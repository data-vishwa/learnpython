# %% [markdown]
# # Basics

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
x = [1,2,3,4,5]
y = [5,7,4,8,11]

# %%
#plt.plot?

# %%
#Line Plot
plt.plot(x,y,linewidth=2,color='red',linestyle='dashed',marker='^',markerfacecolor='blue',markersize=10)
#plt.axis([0,10,0,20])
plt.show()

# %% [markdown]
# # Adding Title and Labels

# %%
plt.xlabel('X label')
plt.ylabel('Y Label')
plt.title('Interesting Graph')
#plt.title('$y=x^2$') #Latex Title
plt.grid()
plt.plot(x,y)

# %% [markdown]
# # Legends

# %%
x2 = [1,2,3,4,5]
y2 = [20,25,24,22,21]

# %%
plt.xlabel('X label')
plt.ylabel('Y Label')
plt.title('Interesting Graph')
plt.plot(x,y,label='First Line')
plt.plot(x2,y2,label='Second Line')
plt.legend(loc='best')

# %% [markdown]
# # Bar Charts and Histograms

# %%
x1 = [10,20,30]
y1 = [50,60,70]
x2 = [15,22,27]
y2 = [150,90,120]

# %%
plt.bar(x1,y1,label='Bars1')
plt.bar(x2,y2,label='Bars2')
plt.legend(loc='best')

# %%
plt.bar(x1,y1,label='Bars1',color='red')
plt.bar(x2,y2,label='Bars2',color='green')
plt.legend(loc='best')

# %%
#Histogram
ages = [12,12,14,15,16,14,22,21,12,22,25]

# %%
plt.hist(ages,color='red',label='Age Distribution',bins=[5,10,15,20,25,30])
plt.legend()

# %%
# with Bins
bins = [5,10,15,20,25,30]
plt.hist(ages,color='red',label='Age Distribution',bins=bins,rwidth=0.8,histtype='bar') # histtype step
plt.legend()

# %% [markdown]
# # Scatterplot

# %%
x = [1,2,3,4,5,6,7,8]
y = [5,2,4,6,12,18,20,25]
plt.scatter(x,y,label='scatter',marker='^',s=50) #marker , #size
plt.legend(loc='best')

# %% [markdown]
# # Stack Plots

# %%
days = [1,2,3,4,5]

sleep = [6,7,8,8,7]
work = [8,8,8,8,10]
play = [3,3,3,2,5]
travel = [3,4,3,4,2]
other = [4,2,2,2,0]

# %%
plt.stackplot(days,sleep,work,play,travel,other,colors=['c','m','g','b','k'])
plt.legend()

# %%
plt.stackplot(days,sleep,work,play,travel,other,colors=['c','m','y','b','k'])
plt.plot([],color='c',label='sleep',linewidth=5)
plt.plot([],color='m',label='work',linewidth=5)
plt.plot([],color='y',label='play',linewidth=5)
plt.plot([],color='b',label='travel',linewidth=5)
plt.plot([],color='k',label='other',linewidth=5)
plt.legend()

# %% [markdown]
# # Pie Charts

# %%
lang = ['python','R','SPSS','SAS','Matplab']
perc = [40,25,15,15,5]

# %%
plt.pie(perc,labels=lang,startangle=90,shadow=True,explode=(0.2,0,0,0,0),autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # working with Dataset

# %%
from sklearn import datasets
iris = datasets.load_iris()
data = iris.data
data.shape

# %%
print(data[:,0])

# %%
print(data[:,1])

# %%
plt.scatter(data[:,0],data[:,1])

# %% [markdown]
# # Some Customization

# %%
x ,y

# %%
#Customizing Ticks
plt.plot(x,y)
plt.xticks([0,2,4,6,8],['a','b','c','d','e'])
plt.yticks([0,5,10,15,20,25,30])
plt.show()

# %% [markdown]
# # Styles

# %%
plt.plot(x,y)

# %%
#from matplotlib import style
with plt.style.context('ggplot'):
    plt.subplot(211)
    plt.plot(x,y)
plt.subplot(212)
plt.plot(x,y)

# %%
plt.style.available

# %%
#Reset Style
#import matplotlib as mpl
#mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# # Annotation & Placing Text

# %%
plt.plot(x,y)
plt.text(3,10,'Hello')
plt.annotate('News',(6,17),xytext=(4,20),arrowprops=dict(facecolor='grey'))

# %% [markdown]
# # Subplots

# %%
#Figure, axes etc
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax1.plot(x,y)
ax1.set_title('First Plot')
ax2.plot(y,x)
ax2.set_title('Second Plot')

#Label Rotation
for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
    
#grid
ax2.grid(True,color='g',linestyle='--',linewidth=1)

#color labels
ax1.set_xlabel('My X label')
ax1.xaxis.label.set_color('green')

#ax3 = fig.add_subplot(2,1,2)
#ax3.plot(y,y)

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((6,2),(0,0),rowspan=2,colspan=2)
ax2 = plt.subplot2grid((6,2),(2,0),rowspan=2,colspan=1)
ax3 = plt.subplot2grid((6,2),(4,0),rowspan=2,colspan=2)
ax4 = plt.subplot2grid((6,2),(2,1),rowspan=2,colspan=1,sharey=ax2)
ax1.plot(x,y)
ax2.scatter(y,x)
ax3.plot(x,x)
ax4.scatter(y,y)
plt.setp(ax4.get_yticklabels(), visible=False)
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

#plt.figure(1)                # figure 1 current; subplot(212) still current
#plt.subplot(211)             # make subplot(211) in figure1 current
#plt.title('Easy as 1, 2, 3') # subplot 211 title

# %% [markdown]
# # Visualizing Numbers as images

# %%
import numpy as np
noise = np.random.random((128,128))
plt.imshow(noise)

# %%
# ?plt.imshow

# %%
from sklearn import datasets

# %%
digits = datasets.load_digits()

# %%
digits.images[0]
# Out:
# array([[  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.],
#        [  0.,   0.,  13.,  15.,  10.,  15.,   5.,   0.],
#        [  0.,   3.,  15.,   2.,   0.,  11.,   8.,   0.],
#        [  0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.],
#        [  0.,   5.,   8.,   0.,   0.,   9.,   8.,   0.],
#        [  0.,   4.,  11.,   0.,   1.,  12.,   7.,   0.],
#        [  0.,   2.,  14.,   5.,  10.,  12.,   0.,   0.],
#        [  0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.]])

# %%
plt.imshow(digits.images[0],cmap=plt.cm.gray_r)
plt.colorbar()
